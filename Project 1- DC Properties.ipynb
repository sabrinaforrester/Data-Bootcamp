# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load csv file data with headers

location = "../datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#show all columns
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#delete columns
cleanup = df.drop(['Unnamed: 0','USECODE', 'STRUCT', 'STYLE','LANDAREA', 'GIS_LAST_MOD_DTTM', 'CMPLX_NUM', 'LIVING_GBA', 'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y'], axis=1)
cleanup.loc[df['YR_RMDL'] < 1980.0]
cleanup.sort_values('YR_RMDL')
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 56600        1          1     Forced Air  Y        1.0      8      4  1929.0
# 72497        1          0     Forced Air  N        1.0      6      3  1948.0
# 12077        2          0     Forced Air  Y        1.0      2      2  1911.0
# 19090        2          0  Hot Water Rad  Y        2.0      8      2  1810.0
# 6187         3          0  Hot Water Rad  N        1.0     12     10  1900.0
# 100883       1          2  Hot Water Rad  N        1.0      7      4  1900.0
# 41941        1          1  Hot Water Rad  N        1.0      7      3  1927.0
# 86850        1          0  Hot Water Rad  Y        1.0      6      2  1900.0
# 41306        4          1  Hot Water Rad  Y        3.0     15      6  1905.0
# 5811         1          0  Hot Water Rad  Y        1.0      5      3  1909.0
# 70889        2          1  Hot Water Rad  N        1.0      9      5  1912.0
# ...

# %%
#count of the Average condition in each zipcode
averagecndtn = (cleanup['CNDTN'] == 'Average')
averagecndtn.groupby(['ZIPCODE']).mean()
#df.groupby(['ZIPCODE', (df['CNDTN'] == 'Average').value_counts()]).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-c31adc4a78d6> in <module>()
#       1 #count of the Average condition in each zipcode
#       2 averagecndtn = (cleanup['CNDTN'] == 'Average')
# ----> 3 averagecndtn.groupby(['ZIPCODE']).mean()
#       4 #df.groupby(['ZIPCODE', (df['CNDTN'] == 'Average').value_counts()]).mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ...

# %%
#count of each zipcode
df['ZIPCODE'].value_counts()
# Out:
# 20011.0    16352
# 20002.0    16310
# 20009.0    13171
# 20019.0    12458
# 20016.0    10644
# 20001.0    10549
# 20020.0     9805
# 20007.0     9029
# 20003.0     8015
# 20008.0     6801
# 20010.0     6428
# 20018.0     5670
# 20017.0     5622
# 20015.0     5337
# 20032.0     5111
# 20012.0     4118
# 20037.0     3730
# 20005.0     3404
# 20024.0     3105
# 20036.0     1892
# 20004.0     1082
# 20392.0      186
# 20006.0      118
# 20052.0       19
# Name: ZIPCODE, dtype: int64

# %%
#count all average conditions
(df['CNDTN'] == 'Average').value_counts()
# Out:
# False    100740
# True      58217
# Name: CNDTN, dtype: int64

# %%
df.sort_values('ZIPCODE')
#cndtnavg = df.loc[df.CNDTN == 'Average']
df[df.CNDTN == 'Average']
df.loc[:, ['ZIPCODE', 'CNDTN']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-185ace419b99> in <module>()
#       2 #cndtnavg = df.loc[df.CNDTN == 'Average']
#       3 df[df.CNDTN == 'Average']
# ----> 4 df.drop([df.CNDTN =='Good','Very Good', 'NaN'], axis = 0)
#       5 df.loc[:, ['ZIPCODE', 'CNDTN']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3617         """
#    3618         labels = com._index_labels_to_array(labels)
# ...
